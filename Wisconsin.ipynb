# %% [markdown]
# # Data Mining on Wiscosin dataset for Breast Cancer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler

# %%
df = pd.read_csv("Data/data_Wisconsin.csv")
df = df.drop(['Unnamed: 32'], axis=1)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
def to_standard(df):
    
    num_df = df[df.select_dtypes(include = np.number).columns.tolist()]
    
    ss = StandardScaler()
    std = ss.fit_transform(num_df)
    
    std_df = pd.DataFrame(std, index = num_df.index, columns = num_df.columns)
    return std_df

# %%
# df = df[['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
        #    'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']]
df = df.dropna()
ax, fig = plt.subplots(1, 1, figsize = (15, 5))
plt.title('The Distribution of Clinical Attributes in the Dataframe', fontsize = 20) #Change please

sns.boxplot(y = "variable", x = "value", data = pd.melt(to_standard(df)), palette = 'Spectral')
plt.xlabel('Range after Standarization', size = 16)
plt.ylabel('Attribue', size = 16)

# fix for mpl bug that cuts off top/bottom of seaborn viz
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.show()

# %% [markdown]
# ## Finding Outliers with two different methods

# %%
df.boxplot(column=['texture_mean', 'radius_mean']);

# %%
df.boxplot(column=['area_mean']);

# %% [markdown]
# **1. Finding outlier using z-score:**

# %%
mask_df = (df[['area_mean', 'texture_mean', 'radius_mean']].apply(zscore) < 3)
mask_df['Drop'] = True
for col in mask_df:
    mask_df['Drop'] &= mask_df[f"{col}"]
df_zscore = df[mask_df['Drop']]
print("df shape: ", df.shape)
print("df after zscore shape: ", df_zscore.shape)
print("Number of outliers that have been removed: ", df.shape[0]-df_zscore.shape[0])
# Out:
# df shape:  (569, 32)
# df after zscore shape:  (557, 32)
# Number of outliers that have been removed:  12

# %% [markdown]
# As we can see, 12 samples are considered as outliers and have been removed from the dataset

# %% [markdown]
# **2. Finding outlier using IQR:**

# %%
Q1 = df['area_mean'].quantile(0.25)
Q3 = df['area_mean'].quantile(0.75)
IQR = Q3 - Q1
filtered = df.query(f'(@Q1 - 1.5 * @IQR) <= area_mean <= (@Q3 + 1.5 * @IQR)')
Q1 = filtered['texture_mean'].quantile(0.25)
Q3 = filtered['texture_mean'].quantile(0.75)
IQR = Q3 - Q1
filtered = filtered.query(f'(@Q1 - 1.5 * @IQR) <= texture_mean <= (@Q3 + 1.5 * @IQR)')
Q1 = filtered['radius_mean'].quantile(0.25)
Q3 = filtered['radius_mean'].quantile(0.75)
IQR = Q3 - Q1
df_IQR = filtered.query(f'(@Q1 - 1.5 * @IQR) <= radius_mean <= (@Q3 + 1.5 * @IQR)')
print("df shape: ", df.shape)
print("df after IQR shape: ", df_IQR.shape)
print("Number of outliers that have been removed: ", df.shape[0]-df_IQR.shape[0])
# Out:
# df shape:  (569, 32)
# df after IQR shape:  (536, 32)
# Number of outliers that have been removed:  33

# %% [markdown]
# As we can see, 33 samples are considered as outliers and have been removed from the dataset

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Normalizing Data

# %%
df.groupby("diagnosis").size().plot(kind='pie', autopct='%1.0f%%', title="Malignant(Orange) or Benign(Blue)");

# %% [markdown]
# 63 Percent of the data are Benign and 37 percent is Malignant

# %%
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(20, 7))

columns = ['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
i = 0
j = 0
for col in columns:
    if j == 5:
        j = 0
        i = 1
    df[col].plot(kind='hist', bins=20, ax=ax[i, j])
    ax[i,j].set_xlabel(col, size=14)
    j+=1

# %% [markdown]
# Our columns are right skewed, so we use inverse square root to normalize the distribution

# %%
columns = ['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
           'compactness_mean']
sec_col = ['concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
for col in columns:
    df[col] = 1/df[col]**(1/2)
for col in sec_col:
    df[col] = df[col]**(1/2)

# %%
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(20, 7))

columns = ['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
i = 0
j = 0
for col in columns:
    if j == 5:
        j = 0
        i = 1
    df[col].plot(kind='hist', bins=20, ax=ax[i, j])
    ax[i,j].set_xlabel(col, size=14)
    j+=1

# %% [markdown]
# ## Classifying numerical columns
# **Finding Natural breaks**

# %%
import jenkspy
columns = ['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
for col in columns:
    breaks = jenkspy.jenks_breaks(df[col], nb_class=3)
    df[f'{col}_natural_breaks'] = pd.cut(df[col], bins=breaks, labels=['Bucket 1', 'Bucket 2', 'Bucket 3'], include_lowest=True)

# %%
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(20, 15))

columns = ['area_mean_natural_breaks', 'texture_mean_natural_breaks', 'radius_mean_natural_breaks', 'perimeter_mean_natural_breaks', 'smoothness_mean_natural_breaks', 
           'compactness_mean_natural_breaks', 'concavity_mean_natural_breaks', 'concave points_mean_natural_breaks', 'symmetry_mean_natural_breaks', 'fractal_dimension_mean_natural_breaks']
i = 0
j = 0
for col in columns:
    if j == 5:
        j = 0
        i = 1
    df.groupby(col).size().plot(kind='bar', ax=ax[i, j])
    ax[i,j].set_xlabel(col, size=12)
    j+=1

# %% [markdown]
# **Binning with qcut**

# %%
columns = ['area_mean', 'texture_mean', 'radius_mean', 'perimeter_mean', 'smoothness_mean', 
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
for col in columns:
    df[f'{col}_bin_qcut'] = pd.qcut(df[col], q=3)

# %%
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(20, 20))
i = 0
j = 0
for col in columns:
    if j == 5:
        j = 0
        i = 1
    df.groupby(f'{col}_bin_qcut').size().plot(kind='bar', ax=ax[i, j])
    ax[i,j].set_xlabel(col, size=12)
    j+=1

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True);

# %%
X = df.drop(['diagnosis'], axis=1)
Y = df.diagnosis
Y = np.where(Y == 'M', 1, 0)

# %%
drop_list = ['perimeter_mean','radius_mean','compactness_mean','concave points_mean','radius_se','perimeter_se','radius_worst','perimeter_worst',
            'compactness_worst','concave points_worst','compactness_se','concave points_se','texture_worst','area_worst']
X_corr = X.drop(drop_list, axis=1)

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(X_corr.corr(), annot=True);

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

BOLD = '\033[1m'
END = '\033[0m'

# %%
from sklearn.model_selection import StratifiedKFold

# using a stratfied k fold because we need the distribution of the to classes in all of the folds to be the same.
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print('Baseline accuracy:' )
print(df.diagnosis.value_counts()/df.diagnosis.count())
# Out:
# Baseline accuracy:
# B    0.627417
# M    0.372583
# Name: diagnosis, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %% [markdown]
# ## KNN

# %%
params = {
    "n_neighbors" : [5,15,25,30,35,40, 100],
    "weights" : ["uniform" , "distance"]
}

model = GridSearchCV(KNeighborsClassifier(), params, n_jobs=-1, cv=4).fit(x_train, y_train)
pred = model.predict(x_test)
results = cross_val_score(model, x_train, y_train, cv=kfold)

knn_pred = model.predict(x_test)
knn_test = model.score(x_test, y_test)
knn_train = results.mean()

print(BOLD + "Model = KNN", END)
print("CV scores: ", results)
print("CV Mean score: ", results.mean())
print('Classification Report:  ')
print(classification_report(y_test, pred))
print("Model's score on train data :", model.score(x_train, y_train))
print("Model's score on test data : ", model.score(x_test, y_test))
cm = confusion_matrix(y_test, pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
print("Best KNN model parameters: ")
print(model.best_estimator_.get_params())
disp.plot();
# Out:
# Model = KNN
# CV scores:  [0.92307692 0.92307692 0.94505495 0.86813187 0.91208791]
# CV Mean score:  0.9142857142857143
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        72
#            1       0.86      0.86      0.86        42
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.89      0.89       114
# weighted avg       0.89      0.89      0.89       114
#
# Model's score on train data : 1.0
# Model's score on test data :  0.8947368421052632
# Best KNN model parameters:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 15, 'p': 2, 'weights': 'distance'}

# %%
MODEL = "Logistic Regression"
params = {
    "C" : np.linspace(0.1, 1.8, 20)
}
model = GridSearchCV(LogisticRegression(max_iter=10000), params, n_jobs=-1, cv=4).fit(x_train, y_train)
pred = model.predict(x_test)
results = cross_val_score(model, x_train, y_train, cv=kfold)

lr_pred = model.predict(x_test)
lr_test = model.score(x_test, y_test)
lr_train = results.mean()

print(BOLD + f"Model = {MODEL}" + END)
print("CV scores: ", results)
print("CV Mean score: ", results.mean())
print('Classification Report:  ')
print(classification_report(y_test, pred))
print("Model's score on train data :", model.score(x_train, y_train))
print("Model's score on test data : ", model.score(x_test, y_test))
cm = confusion_matrix(y_test, pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
print(f"Best {MODEL} model parameters: ")
print(model.best_estimator_.get_params())
disp.plot();
# Out:
# Model = Logistic Regression
# CV scores:  [0.92307692 0.95604396 0.95604396 0.92307692 0.95604396]
# CV Mean score:  0.9428571428571428
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        72
#            1       0.93      0.95      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Model's score on train data : 0.9582417582417583
# Model's score on test data :  0.956140350877193
# Best Logistic Regression model parameters:
# {'C': 0.6368421052631579, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 10000, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
MODEL = "Decision Tree Classifier"

model = DecisionTreeClassifier().fit(x_train, y_train)
pred = model.predict(x_test)
results = cross_val_score(model, x_train, y_train, cv=kfold)

dt_pred = model.predict(x_test)
dt_test = model.score(x_test, y_test)
dt_train = results.mean()

print(BOLD + f"Model = {MODEL}" + END)
print("CV scores: ", results)
print("CV Mean score: ", results.mean())
print('Classification Report:  ')
print(classification_report(y_test, pred))
print("Model's score on train data :", model.score(x_train, y_train))
print("Model's score on test data : ", model.score(x_test, y_test))
cm = confusion_matrix(y_test, pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
print(f"Best {MODEL} model parameters: ")
print(model.get_params())
disp.plot();
# Out:
# Model = Decision Tree Classifier
# CV scores:  [0.92307692 0.94505495 0.93406593 0.9010989  0.94505495]
# CV Mean score:  0.9296703296703296
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        72
#            1       0.95      0.90      0.93        42
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Model's score on train data : 1.0
# Model's score on test data :  0.9473684210526315
# Best Decision Tree Classifier model parameters:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}

# %%
MODEL = "Random Forest Classifier"

model = RandomForestClassifier().fit(x_train, y_train)
pred = model.predict(x_test)
results = cross_val_score(model, x_train, y_train, cv=kfold)

rf_pred = model.predict(x_test)
rf_test = model.score(x_test, y_test)
rf_train = results.mean()

print(BOLD + f"Model = {MODEL}" + END)
print("CV scores: ", results)
print("CV Mean score: ", results.mean())
print('Classification Report:  ')
print(classification_report(y_test, pred))
print("Model's score on train data :", model.score(x_train, y_train))
print("Model's score on test data : ", model.score(x_test, y_test))
cm = confusion_matrix(y_test, pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
print(f"Best {MODEL} model parameters: ")
print(model.get_params())
disp.plot();
# Out:
# Model = Random Forest Classifier
# CV scores:  [0.91208791 0.95604396 0.93406593 0.93406593 0.98901099]
# CV Mean score:  0.945054945054945
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        72
#            1       0.95      0.93      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Model's score on train data : 1.0
# Model's score on test data :  0.956140350877193
# Best Random Forest Classifier model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
MODEL = "MLP Classifier"

# , (100, 100, 50, 50, 10), (150, 100, 70, 50, 10)
# , 1e-2, 1e-1, 1
# params = {
#     "hidden_layer_sizes" : [(100, 200, 100, 50, 10)],
#     "solver" : ['adam'],
#     "alpha" : [1e-4, 1e-3],
#     "learning_rate_init" : [1e-3, 1e-2, 1e-1],
#     "max_iter" : [1000,]
# }
# model = GridSearchCV(MLPClassifier(), params, n_jobs=-1, cv=4).fit(x_train, y_train)
model = MLPClassifier(hidden_layer_sizes=(100, 50, 10), max_iter=1000).fit(x_train, y_train)
pred = model.predict(x_test)
results = cross_val_score(model, x_train, y_train, cv=kfold)

mlp_pred = model.predict(x_test)
mlp_test = model.score(x_test, y_test)
mlp_train = results.mean()

print(BOLD + f"Model = {MODEL}" + END)
print("CV scores: ", results)
print("CV Mean score: ", results.mean())
print('Classification Report:  ')
print(classification_report(y_test, pred))
print("Model's score on train data :", model.score(x_train, y_train))
print("Model's score on test data : ", model.score(x_test, y_test))
cm = confusion_matrix(y_test, pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
print(f"Best {MODEL} model parameters: ")
print(model.get_params())
disp.plot();
# Out:
# Model = MLP Classifier
# CV scores:  [0.92307692 0.94505495 0.95604396 0.91208791 0.93406593]
# CV Mean score:  0.9340659340659341
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.69      0.81        72
#            1       0.65      0.95      0.77        42
#
#     accuracy                           0.79       114
#    macro avg       0.80      0.82      0.79       114
# weighted avg       0.84      0.79      0.79       114
#
# Model's score on train data : 0.8483516483516483
# Model's score on test data :  0.7894736842105263
# Best MLP Classifier model parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 50, 10), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}

# %%
def subplot_bargraph(dataframe, list_of_columns, list_of_titles, list_of_xlabels, big_title_name):
    
    nrows = int(np.ceil(len(list_of_columns)/3)) # Makes sure you have enough rows
    fig, ax = plt.subplots(ncols=3,nrows=nrows, figsize=(15, 10)) # You'll want to specify your figsize
    fig.suptitle(big_title_name, fontsize=20)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        sns.countplot(dataframe[column].dropna(), color= 'teal', ax=ax[i], hue=dataframe['eventdeath']) # feel free to add more settings
        #ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_xlabel('')
        ax[i].set_ylabel('Frequency')
        ax[i].set_title(list_of_titles[i]) # Set titles, labels, etc here for each subplot    
    plt.show()

# %%
from sklearn.metrics import auc, roc_curve

fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(15,6))

color= "Spectral"


#bar chart of accuracy scores
inds = range(1,5)
labels = ["KNN", "Logistic Regression", "Decision Tree", "Random Forest"]

scores_all = [knn_train, lr_train, dt_train, rf_train]
scores_predictive = [knn_test, lr_test, dt_test, rf_test]

ax1.bar(inds, scores_all, color=sns.color_palette(color)[5], alpha=0.3, hatch="x", edgecolor="none",label="CrossValidation Set")
ax1.bar(inds, scores_predictive, color=sns.color_palette(color)[0], label="Testing set")
ax1.set_ylim(0.4, 1)
ax1.set_ylabel("Accuracy score")
ax1.axhline(0.5793, color="black", linestyle="--")
ax1.set_title("Accuracy scores for basic models", fontsize=17)
ax1.set_xticks(range(1,5))
ax1.set_xticklabels(labels, size=12, rotation=40, ha="right")
ax1.legend()

labels = ["KNN", "Logistic Regression", "Decision Tree", "Random Forest"]
for label, pred in zip(labels, [knn_pred, lr_pred, dt_pred, rf_pred]):
    fpr, tpr, threshold = roc_curve(y_test, pred)
    roc_auc = auc(fpr, tpr)
    ax2.plot(fpr, tpr, label=label+' (area = %0.2f)' % roc_auc, linewidth=2)
    ax2.plot([0, 1], [0, 1], 'k--', linewidth=2)
    ax2.set_xlim([-0.05, 1.0])
    ax2.set_ylim([-0.05, 1.05])
    ax2.set_xlabel('False Positive Rate')
    ax2.set_ylabel('True Positive Rate')
    ax2.legend(loc="lower right", prop={'size': 12})
    ax2.set_title("Roc curve for for basic models", fontsize=17)

plt.show()

# %%
roc_curve()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20088/3967890411.py in <module>
# ----> 1 roc_curve()
#
# TypeError: roc_curve() missing 2 required positional arguments: 'y_true' and 'y_score'

# %%
mlp_pred
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B'], dtype='<U1')
